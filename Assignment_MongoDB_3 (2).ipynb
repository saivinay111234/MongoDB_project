# %% [markdown]
# ## Loading the required libraries

# %% [markdown]
# The Data is collected from the Kaggle website. intially the data is in comma seperated values format (CSV), I have converted the file into json format using the website "https://csvjson.com/csv2json".
#
# Data Source: https://www.kaggle.com/datasets/sujaykapadnis/cats-vs-dogs
#
# Code Explanation:
# 1. import json: This line imports the json module, which provides functions for working with JSON data in Python.
#
# 2. with open("C:/Users/saivi/bd-f23/bd-f23/catsvsdogsjson.json", "r") as json_file:: This line uses a context manager (the with statement) to open the JSON file located at the specified path ("C:/Users/saivi/bd-f23/bd-f23/catsvsdogsjson.json") in read mode ("r"). The as keyword is used to create an alias for the opened file, and it is named json_file.
#
# 3. cvd=json.load(json_file): Inside the context block, this line reads the contents of the opened JSON file using the json.load() function. It parses the JSON data from the json_file and stores it in the cvd variable as a Python dictionary.

# %%
import json

with open("C:/Users/saivi/bd-f23/bd-f23/catsvsdogsjson.json", "r") as json_file:
    cvd=json.load(json_file)

# %%
print(json.dumps(cvd, indent=4))
# Out:
# [
#     {
#         "": 1,
#         "state": "Alabama",
#         "n_households": 1828,
#         "percent_pet_households": 59.5,
#         "n_pet_households": 1088,
#         "percent_dog_owners": 44.1,
#         "n_dog_households": 807,
#         "avg_dogs_per_household": 1.7,
#         "dog_population": 1410,
#         "percent_cat_owners": 27.4,
#         "n_cat_households": 501,
#         "avg_cats_per_household": 2.5,
#         "cat_population": 1252
#     },
#     {
#         "": 2,
#         "state": "Arizona",
#         "n_households": 2515,
#         "percent_pet_households": 59.5,
#         "n_pet_households": 1497,
#         "percent_dog_owners": 40.1,
#         "n_dog_households": 1008,
#         "avg_dogs_per_household": 1.8,
#         "dog_population": 1798,
#         "percent_cat_owners": 29.6,
#         "n_cat_households": 743,
#         "avg_cats_per_household": 1.9,
#         "cat_population": 1438
#     },
#     {
#         "": 3,
#         "state": "Arkansas",
#         "n_households": 1148,
#         "percent_pet_households": 62.4,
#         "n_pet_households": 716,
#         "percent_dog_owners": 47.9,
#         "n_dog_households": 550,
#         "avg_dogs_per_household": 2,
#         "dog_population": 1097,
#         "percent_cat_owners": 30.6,
#         "n_cat_households": 351,
#         "avg_cats_per_household": 2.3,
#         "cat_population": 810
#     },
#     {
#         "": 4,
#         "state": "California",
#         "n_households": 12974,
#         "percent_pet_households": 52.9,
#         "n_pet_households": 6865,
#         "percent_dog_owners": 32.8,
#         "n_dog_households": 4260,
#         "avg_dogs_per_household": 1.6,
#         "dog_population": 6687,
#         "percent_cat_owners": 28.3,
#         "n_cat_households": 3687,
#         "avg_cats_per_household": 1.9,
#         "cat_population": 7118
#     },
#     {
#         "": 5,
#         "state": "Colorado",
#         "n_households": 1986,
#         "percent_pet_households": 61.3,
#         "n_pet_households": 1217,
#         "percent_dog_owners": 42.5,
#         "n_dog_households": 845,
#         "avg_dogs_per_household": 1.6,
#         "dog_population": 1349,
#         "percent_cat_owners": 32.3,
#         "n_cat_households": 642,
#         "avg_cats_per_household": 1.9,
#         "cat_population": 1191
#     },
#     {
#         "": 6,
#         "state": "Connecticut",
#         "n_households": 1337,
#         "percent_pet_households": 54.4,
#         "n_pet_households": 728,
#         "percent_dog_owners": 28.3,
#         "n_dog_households": 379,
#         "avg_dogs_per_household": 1.3,
#         "dog_population": 507,
#         "percent_cat_owners": 31.9,
#         "n_cat_households": 427,
#         "avg_cats_per_household": 1.9,
#         "cat_population": 796
#     },
#     {
#         "": 7,
#         "state": "Delaware",
#         "n_households": 334,
#         "percent_pet_households": 56.6,
#         "n_pet_households": 189,
#         "percent_dog_owners": 33.7,
#         "n_dog_households": 113,
#         "avg_dogs_per_household": 1.4,
#         "dog_population": 163,
#         "percent_cat_owners": 33.7,
#         "n_cat_households": 113,
#         "avg_cats_per_household": 1.7,
#         "cat_population": 187
#     },
#     {
#         "": 8,
#         "state": "District of Columbia",
#         "n_households": 287,
#         "percent_pet_households": 21.9,
#         "n_pet_households": 63,
#         "percent_dog_owners": 13.1,
#         "n_dog_households": 38,
#         "avg_dogs_per_household": 1.1,
#         "dog_population": 42,
#         "percent_cat_owners": 11.6,
#         "n_cat_households": 33,
#         "avg_cats_per_household": 1.9,
#         "cat_population": 63
#     },
#     {
#         "": 9,
#         "state": "Florida",
#         "n_households": 7609,
#         "percent_pet_households": 54.4,
#         "n_pet_households": 4138,
#         "percent_dog_owners": 35.7,
#         "n_dog_households": 2718,
#         "avg_dogs_per_household": 1.5,
#         "dog_population": 4210,
#         "percent_cat_owners": 27.3,
#         "n_cat_households": 2079,
#         "avg_cats_per_household": 2.1,
#         "cat_population": 4375
#     },
#     {
#         "": 10,
#         "state": "Georgia",
#         "n_households": 3798,
#         "percent_pet_households": 55.1,
#         "n_pet_households": 2093,
#         "percent_dog_owners": 40.1,
#         "n_dog_households": 1522,
#         "avg_dogs_per_household": 1.6,
#         "dog_population": 2479,
#         "percent_cat_owners": 27.3,
#         "n_cat_households": 1037,
#         "avg_cats_per_household": 2.1,
#         "cat_population": 2162
#     },
#     {
#         "": 11,
#         "state": "Idaho",
#         "n_households": 568,
#         "percent_pet_households": 62,
#         "n_pet_households": 352,
#         "percent_dog_owners": 42.7,
#         "n_dog_households": 242,
#         "avg_dogs_per_household": 1.5,
#         "dog_population": 357,
#         "percent_cat_owners": 34.6,
#         "n_cat_households": 196,
#         "avg_cats_per_household": 2,
#         "cat_population": 393
#     },
#     {
#         "": 12,
#         "state": "Illinois",
#         "n_households": 5026,
#         "percent_pet_households": 51.8,
#         "n_pet_households": 2602,
#         "percent_dog_owners": 32.4,
#         "n_dog_households": 1627,
#         "avg_dogs_per_household": 1.5,
#         "dog_population": 2365,
#         "percent_cat_owners": 26.3,
#         "n_cat_households": 1321,
#         "avg_cats_per_household": 1.9,
#         "cat_population": 2453
#     },
#     {
#         "": 13,
#         "state": "Indiana",
#         "n_households": 2478,
#         "percent_pet_households": 59.9,
#         "n_pet_households": 1484,
#         "percent_dog_owners": 39.9,
#         "n_dog_households": 989,
#         "avg_dogs_per_household": 1.6,
#         "dog_population": 1619,
#         "percent_cat_owners": 34.4,
#         "n_cat_households": 852,
#         "avg_cats_per_household": 2.2,
#         "cat_population": 1912
#     },
#     {
#         "": 14,
#         "state": "Iowa",
#         "n_households": 1219,
#         "percent_pet_households": 53.6,
#         "n_pet_households": 654,
#         "percent_dog_owners": 33.4,
#         "n_dog_households": 407,
#         "avg_dogs_per_household": 1.5,
#         "dog_population": 610,
#         "percent_cat_owners": 30.3,
#         "n_cat_households": 370,
#         "avg_cats_per_household": 2.2,
#         "cat_population": 805
#     },
#     {
#         "": 15,
#         "state": "Kansas",
#         "n_households": 1133,
#         "percent_pet_households": 61,
#         "n_pet_households": 691,
#         "percent_dog_owners": 42.3,
#         "n_dog_households": 480,
#         "avg_dogs_per_household": 1.6,
#         "dog_population": 774,
#         "percent_cat_owners": 33.3,
#         "n_cat_households": 378,
#         "avg_cats_per_household": 1.9,
#         "cat_population": 731
#     },
#     {
#         "": 16,
#         "state": "Kentucky",
#         "n_households": 1777,
#         "percent_pet_households": 61.6,
#         "n_pet_households": 1094,
#         "percent_dog_owners": 45.9,
#         "n_dog_households": 816,
#         "avg_dogs_per_household": 1.9,
#         "dog_population": 1531,
#         "percent_cat_owners": 36.8,
#         "n_cat_households": 654,
#         "avg_cats_per_household": 2.1,
#         "cat_population": 1349
#     },
#     {
#         "": 17,
#         "state": "Louisiana",
#         "n_households": 1702,
#         "percent_pet_households": 55.1,
#         "n_pet_households": 937,
#         "percent_dog_owners": 36.4,
#         "n_dog_households": 619,
#         "avg_dogs_per_household": 1.8,
#         "dog_population": 1115,
#         "percent_cat_owners": 25.9,
#         "n_cat_households": 441,
#         "avg_cats_per_household": 2,
#         "cat_population": 877
#     },
#     {
#         "": 18,
#         "state": "Maine",
#         "n_households": 548,
#         "percent_pet_households": 62.9,
#         "n_pet_households": 345,
#         "percent_dog_owners": 34.6,
#         "n_dog_households": 190,
#         "avg_dogs_per_household": 1.6,
#         "dog_population": 300,
#         "percent_cat_owners": 46.4,
#         "n_cat_households": 254,
#         "avg_cats_per_household": 1.9,
#         "cat_population": 498
#     },
#     {
#         "": 19,
#         "state": "Maryland",
#         "n_households": 2169,
#         "percent_pet_households": 52.3,
#         "n_pet_households": 1134,
#         "percent_dog_owners": 30.8,
#         "n_dog_households": 667,
#         "avg_dogs_per_household": 1.4,
#         "dog_population": 915,
#         "percent_cat_owners": 29.8,
#         "n_cat_households": 645,
#         "avg_cats_per_household": 2.6,
#         "cat_population": 1677
#     },
#     {
#         "": 20,
#         "state": "Massachusetts",
#         "n_households": 2618,
#         "percent_pet_households": 50.4,
#         "n_pet_households": 1318,
#         "percent_dog_owners": 23.6,
#         "n_dog_households": 618,
#         "avg_dogs_per_household": 1.4,
#         "dog_population": 850,
#         "percent_cat_owners": 34.1,
#         "n_cat_households": 892,
#         "avg_cats_per_household": 1.8,
#         "cat_population": 1593
#     },
#     {
#         "": 21,
#         "state": "Michigan",
#         "n_households": 3804,
#         "percent_pet_households": 55.4,
#         "n_pet_households": 2108,
#         "percent_dog_owners": 34.6,
#         "n_dog_households": 1318,
#         "avg_dogs_per_household": 1.5,
#         "dog_population": 2036,
#         "percent_cat_owners": 31.3,
#         "n_cat_households": 1192,
#         "avg_cats_per_household": 2,
#         "cat_population": 2420
#     },
#     {
#         "": 22,
#         "state": "Minnesota",
#         "n_households": 2163,
#         "percent_pet_households": 53,
#         "n_pet_households": 1146,
#         "percent_dog_owners": 31.9,
#         "n_dog_households": 690,
#         "avg_dogs_per_household": 1.4,
#         "dog_population": 934,
#         "percent_cat_owners": 29.7,
#         "n_cat_households": 643,
#         "avg_cats_per_household": 2,
#         "cat_population": 1264
#     },
#     {
#         "": 23,
#         "state": "Mississippi",
#         "n_households": 1115,
#         "percent_pet_households": 56.4,
#         "n_pet_households": 629,
#         "percent_dog_owners": 45.2,
#         "n_dog_households": 504,
#         "avg_dogs_per_household": 1.7,
#         "dog_population": 846,
#         "percent_cat_owners": 29.1,
#         "n_cat_households": 324,
#         "avg_cats_per_household": 2.1,
#         "cat_population": 668
#     },
#     {
#         "": 24,
#         "state": "Missouri",
#         "n_households": 2498,
#         "percent_pet_households": 61.4,
#         "n_pet_households": 1534,
#         "percent_dog_owners": 45.9,
#         "n_dog_households": 1148,
#         "avg_dogs_per_household": 1.7,
#         "dog_population": 1978,
#         "percent_cat_owners": 32.2,
#         "n_cat_households": 805,
#         "avg_cats_per_household": 2.1,
#         "cat_population": 1653
#     },
#     {
#         "": 25,
#         "state": "Montana",
#         "n_households": 410,
#         "percent_pet_households": 61.3,
#         "n_pet_households": 251,
#         "percent_dog_owners": 41.2,
#         "n_dog_households": 169,
#         "avg_dogs_per_household": 1.7,
#         "dog_population": 282,
#         "percent_cat_owners": 33.6,
#         "n_cat_households": 138,
#         "avg_cats_per_household": 2,
#         "cat_population": 277
#     },
#     {
#         "": 26,
#         "state": "Nebraska",
#         "n_households": 710,
#         "percent_pet_households": 51.3,
#         "n_pet_households": 364,
#         "percent_dog_owners": 33.8,
#         "n_dog_households": 240,
#         "avg_dogs_per_household": 1.6,
#         "dog_population": 374,
#         "percent_cat_owners": 31.3,
#         "n_cat_households": 222,
#         "avg_cats_per_household": 2.3,
#         "cat_population": 514
#     },
#     {
#         "": 27,
#         "state": "Nevada",
#         "n_households": 986,
#         "percent_pet_households": 55.6,
#         "n_pet_households": 548,
#         "percent_dog_owners": 37.1,
#         "n_dog_households": 366,
#         "avg_dogs_per_household": 1.6,
#         "dog_population": 578,
#         "percent_cat_owners": 30.3,
#         "n_cat_households": 299,
#         "avg_cats_per_household": 2.1,
#         "cat_population": 625
#     },
#     {
#         "": 28,
#         "state": "New Hampshire",
#         "n_households": 508,
#         "percent_pet_households": 56.8,
#         "n_pet_households": 289,
#         "percent_dog_owners": 30.3,
#         "n_dog_households": 154,
#         "avg_dogs_per_household": 1.4,
#         "dog_population": 212,
#         "percent_cat_owners": 34.2,
#         "n_cat_households": 174,
#         "avg_cats_per_household": 1.8,
#         "cat_population": 309
#     },
#     {
#         "": 29,
#         "state": "New Jersey",
#         "n_households": 3177,
#         "percent_pet_households": 50.7,
#         "n_pet_households": 1611,
#         "percent_dog_owners": 32.4,
#         "n_dog_households": 1028,
#         "avg_dogs_per_household": 1.3,
#         "dog_population": 1340,
#         "percent_cat_owners": 25.3,
#         "n_cat_households": 803,
#         "avg_cats_per_household": 1.8,
#         "cat_population": 1468
#     },
#     {
#         "": 30,
#         "state": "New Mexico",
#         "n_households": 773,
#         "percent_pet_households": 67.6,
#         "n_pet_households": 523,
#         "percent_dog_owners": 46,
#         "n_dog_households": 356,
#         "avg_dogs_per_household": 2,
#         "dog_population": 703,
#         "percent_cat_owners": 32,
#         "n_cat_households": 247,
#         "avg_cats_per_household": 2.2,
#         "cat_population": 533
#     },
#     {
#         "": 31,
#         "state": "New York",
#         "n_households": 7512,
#         "percent_pet_households": 50.6,
#         "n_pet_households": 3802,
#         "percent_dog_owners": 29,
#         "n_dog_households": 2177,
#         "avg_dogs_per_household": 1.4,
#         "dog_population": 3054,
#         "percent_cat_owners": 29.1,
#         "n_cat_households": 2189,
#         "avg_cats_per_household": 1.9,
#         "cat_population": 4261
#     },
#     {
#         "": 32,
#         "state": "North Carolina",
#         "n_households": 3701,
#         "percent_pet_households": 56.4,
#         "n_pet_households": 2089,
#         "percent_dog_owners": 40.3,
#         "n_dog_households": 1491,
#         "avg_dogs_per_household": 1.7,
#         "dog_population": 2518,
#         "percent_cat_owners": 29.5,
#         "n_cat_households": 1090,
#         "avg_cats_per_household": 2,
#         "cat_population": 2220
#     },
#     {
#         "": 33,
#         "state": "North Dakota",
#         "n_households": 272,
#         "percent_pet_households": 53.9,
#         "n_pet_households": 147,
#         "percent_dog_owners": 36.1,
#         "n_dog_households": 98,
#         "avg_dogs_per_household": 1.4,
#         "dog_population": 139,
#         "percent_cat_owners": 31.4,
#         "n_cat_households": 85,
#         "avg_cats_per_household": 2,
#         "cat_population": 174
#     },
#     {
#         "": 34,
#         "state": "Ohio",
#         "n_households": 4661,
#         "percent_pet_households": 57.4,
#         "n_pet_households": 2677,
#         "percent_dog_owners": 36.6,
#         "n_dog_households": 1708,
#         "avg_dogs_per_household": 1.6,
#         "dog_population": 2730,
#         "percent_cat_owners": 33.3,
#         "n_cat_households": 1553,
#         "avg_cats_per_household": 2.4,
#         "cat_population": 3786
#     },
#     {
#         "": 35,
#         "state": "Oklahoma",
#         "n_households": 1479,
#         "percent_pet_households": 58.9,
#         "n_pet_households": 872,
#         "percent_dog_owners": 43.2,
#         "n_dog_households": 638,
#         "avg_dogs_per_household": 2.1,
#         "dog_population": 1327,
#         "percent_cat_owners": 32.6,
#         "n_cat_households": 482,
#         "avg_cats_per_household": 2.2,
#         "cat_population": 1041
#     },
#     {
#         "": 36,
#         "state": "Oregon",
#         "n_households": 1505,
#         "percent_pet_households": 63.6,
#         "n_pet_households": 957,
#         "percent_dog_owners": 38.8,
#         "n_dog_households": 584,
#         "avg_dogs_per_household": 1.6,
#         "dog_population": 917,
#         "percent_cat_owners": 40.2,
#         "n_cat_households": 605,
#         "avg_cats_per_household": 2,
#         "cat_population": 1185
#     },
#     {
#         "": 37,
#         "state": "Pennsylvania",
#         "n_households": 5172,
#         "percent_pet_households": 56.9,
#         "n_pet_households": 2942,
#         "percent_dog_owners": 32.9,
#         "n_dog_households": 1702,
#         "avg_dogs_per_household": 1.5,
#         "dog_population": 2485,
#         "percent_cat_owners": 33.8,
#         "n_cat_households": 1748,
#         "avg_cats_per_household": 2,
#         "cat_population": 3544
#     },
#     {
#         "": 38,
#         "state": "Rhode Island",
#         "n_households": 434,
#         "percent_pet_households": 53,
#         "n_pet_households": 230,
#         "percent_dog_owners": 29.3,
#         "n_dog_households": 127,
#         "avg_dogs_per_household": 1.3,
#         "dog_population": 161,
#         "percent_cat_owners": 27.6,
#         "n_cat_households": 120,
#         "avg_cats_per_household": 1.8,
#         "cat_population": 212
#     },
#     {
#         "": 39,
#         "state": "South Carolina",
#         "n_households": 1759,
#         "percent_pet_households": 54.1,
#         "n_pet_households": 951,
#         "percent_dog_owners": 38.6,
#         "n_dog_households": 678,
#         "avg_dogs_per_household": 1.8,
#         "dog_population": 1191,
#         "percent_cat_owners": 27.8,
#         "n_cat_households": 490,
#         "avg_cats_per_household": 2.1,
#         "cat_population": 1039
#     },
#     {
#         "": 40,
#         "state": "South Dakota",
#         "n_households": 333,
#         "percent_pet_households": 65.6,
#         "n_pet_households": 219,
#         "percent_dog_owners": 42.8,
#         "n_dog_households": 143,
#         "avg_dogs_per_household": 1.5,
#         "dog_population": 220,
#         "percent_cat_owners": 39.1,
#         "n_cat_households": 130,
#         "avg_cats_per_household": 2.2,
#         "cat_population": 290
#     },
#     {
#         "": 41,
#         "state": "Tennessee",
#         "n_households": 2583,
#         "percent_pet_households": 59.6,
#         "n_pet_households": 1540,
#         "percent_dog_owners": 44.1,
#         "n_dog_households": 1140,
#         "avg_dogs_per_household": 1.9,
#         "dog_population": 2157,
#         "percent_cat_owners": 29.8,
#         "n_cat_households": 770,
#         "avg_cats_per_household": 2.3,
#         "cat_population": 1749
#     },
#     {
#         "": 42,
#         "state": "Texas",
#         "n_households": 9002,
#         "percent_pet_households": 58.5,
#         "n_pet_households": 5265,
#         "percent_dog_owners": 44,
#         "n_dog_households": 3960,
#         "avg_dogs_per_household": 1.8,
#         "dog_population": 7163,
#         "percent_cat_owners": 28.3,
#         "n_cat_households": 2544,
#         "avg_cats_per_household": 2.2,
#         "cat_population": 5565
#     },
#     {
#         "": 43,
#         "state": "Utah",
#         "n_households": 930,
#         "percent_pet_households": 51.2,
#         "n_pet_households": 476,
#         "percent_dog_owners": 29.4,
#         "n_dog_households": 273,
#         "avg_dogs_per_household": 1.5,
#         "dog_population": 410,
#         "percent_cat_owners": 24.6,
#         "n_cat_households": 229,
#         "avg_cats_per_household": 2,
#         "cat_population": 455
#     },
#     {
#         "": 44,
#         "state": "Vermont",
#         "n_households": 265,
#         "percent_pet_households": 70.8,
#         "n_pet_households": 188,
#         "percent_dog_owners": 37.7,
#         "n_dog_households": 100,
#         "avg_dogs_per_household": 1.4,
#         "dog_population": 142,
#         "percent_cat_owners": 49.5,
#         "n_cat_households": 131,
#         "avg_cats_per_household": 1.8,
#         "cat_population": 234
#     },
#     {
#         "": 45,
#         "state": "Virginia",
#         "n_households": 3017,
#         "percent_pet_households": 53.4,
#         "n_pet_households": 1611,
#         "percent_dog_owners": 35.4,
#         "n_dog_households": 1069,
#         "avg_dogs_per_household": 1.6,
#         "dog_population": 1699,
#         "percent_cat_owners": 29,
#         "n_cat_households": 876,
#         "avg_cats_per_household": 2.1,
#         "cat_population": 1855
#     },
#     {
#         "": 46,
#         "state": "Washington",
#         "n_households": 2632,
#         "percent_pet_households": 62.7,
#         "n_pet_households": 1649,
#         "percent_dog_owners": 36.3,
#         "n_dog_households": 954,
#         "avg_dogs_per_household": 1.7,
#         "dog_population": 1609,
#         "percent_cat_owners": 39,
#         "n_cat_households": 1028,
#         "avg_cats_per_household": 1.8,
#         "cat_population": 1844
#     },
#     {
#         "": 47,
#         "state": "West Virginia",
#         "n_households": 765,
#         "percent_pet_households": 62.1,
#         "n_pet_households": 475,
#         "percent_dog_owners": 45.8,
#         "n_dog_households": 350,
#         "avg_dogs_per_household": 1.8,
#         "dog_population": 648,
#         "percent_cat_owners": 38.1,
#         "n_cat_households": 291,
#         "avg_cats_per_household": 2.2,
#         "cat_population": 628
#     },
#     {
#         "": 48,
#         "state": "Wisconsin",
#         "n_households": 2350,
#         "percent_pet_households": 57.5,
#         "n_pet_households": 1352,
#         "percent_dog_owners": 33.9,
#         "n_dog_households": 796,
#         "avg_dogs_per_household": 1.4,
#         "dog_population": 1138,
#         "percent_cat_owners": 33,
#         "n_cat_households": 776,
#         "avg_cats_per_household": 1.9,
#         "cat_population": 1510
#     },
#     {
#         "": 49,
#         "state": "Wyoming",
#         "n_households": 221,
#         "percent_pet_households": 61.8,
#         "n_pet_households": 137,
#         "percent_dog_owners": 38.8,
#         "n_dog_households": 86,
#         "avg_dogs_per_household": 1.5,
#         "dog_population": 125,
#         "percent_cat_owners": 33.9,
#         "n_cat_households": 75,
#         "avg_cats_per_household": 1.9,
#         "cat_population": 144
#     }
# ]

# %% [markdown]
# ## Load the Cats vs Dogs data into MongoDB

# %% [markdown]
# 1. import pymongo: This line imports the pymongo module, which is a Python driver for MongoDB, allowing you to interact with MongoDB databases in your Python code.
#
# 2. import credential_ak: Assuming you have a module named credential_ak containing your MongoDB credentials (such as username and password), you import it here. This is a common practice to keep sensitive information separate from your main code.
#
# 3. connection_string = f"mongodb+srv://{credential_ak.username}:{credential_ak.password}@cluster1.cs30gni.mongodb.net/?retryWrites=true&w=majority": This line creates a connection string by formatting the MongoDB credentials (username and password) obtained from the credential_ak module. This connection string can be used to connect to a MongoDB cluster hosted at the specified URI (cluster1.cs30gni.mongodb.net). The retryWrites=true&w=majority parameters are common options used for MongoDB Atlas clusters to ensure write operations are retried and to specify write concern.

# %%
import pymongo
import credential_ak

connection_string = f"mongodb+srv://{credential_ak.username}:{credential_ak.password}@cluster1.cs30gni.mongodb.net/?retryWrites=true&w=majority"

# %% [markdown]
# ## Laod the Cats vs dogs data into MongoDB

# %% [markdown]
# import pymongo: This line imports the pymongo module, which is used for MongoDB operations in Python.
#
# import credential_ak: I import a module named credential_ak containing my MongoDB credentials to use the connection_string.
#
# client = pymongo.MongoClient(connection_string): Here, I create a MongoClient instance using the connection_string I've defined earlier. This client allows me to connect to my MongoDB database.
#
# db = client['Assignment_MongoDB_3']: I access the database named 'Assignment_MongoDB_3' within the MongoDB server.
#
# collection = db['Cats vs Dogs Data']: I access the collection named 'Cats vs Dogs Data' within the database. Collections are similar to tables in traditional databases.
#
# cvd_json = collection.insert_many(cvd): This line inserts multiple JSON documents (presumably stored in the cvd variable) into the 'Cats vs Dogs Data' collection using the insert_many method. It's a way for me to populate the MongoDB collection with data from the cvd variable.

# %%
client=pymongo.MongoClient(connection_string)
db=client['Assignment_MongoDB_3']
collection=db['Cats vs Dogs Data']
cvd_json=collection.insert_many(cvd)

# %% [markdown]
# ## Querying the data

# %% [markdown]
# I import the necessary modules, including json and ObjectId from bson. I define a query to find documents in the MongoDB collection where the "state" field is equal to "Alabama." I then use the collection's find method with the query to retrieve matching documents. For each document found, I convert its ObjectId to a string, format the document as JSON with proper indentation, and print it to the console. This code allows me to retrieve and display JSON-formatted data for documents matching the specified query in the collection.

# %%
import json
from bson import ObjectId

query={"state":"Alabama"}
doc=collection.find(query)
for record in doc:
    record["_id"] = str(record["_id"])
    json_data=json.dumps(record, indent=4)
    print(json_data)
# Out:
# {
#     "_id": "6511be7c30e613232b62647c",
#     "": 1,
#     "state": "Alabama",
#     "n_households": 1828,
#     "percent_pet_households": 59.5,
#     "n_pet_households": 1088,
#     "percent_dog_owners": 44.1,
#     "n_dog_households": 807,
#     "avg_dogs_per_household": 1.7,
#     "dog_population": 1410,
#     "percent_cat_owners": 27.4,
#     "n_cat_households": 501,
#     "avg_cats_per_household": 2.5,
#     "cat_population": 1252
# }

# %% [markdown]
# ## Aggregating the Data
#
# This code defines an aggregation pipeline in MongoDB to calculate the average values for "n_households," "dog_population," and "cat_population" across all documents in the collection. It then executes the pipeline and prints the result in JSON format with proper indentation. If no data is found, it prints "No data found."

# %%
# Define the aggregation pipeline
pipeline = [
    {
        "$group": {
            "_id": None,
            "avg_n_households": {"$avg": "$n_households"},
            "avg_dog_population": {"$avg": "$dog_population"},
            "avg_cat_population": {"$avg": "$cat_population"}
        }
    },
    {
        "$project": {
            "_id": 0,
            "avg_n_households": 1,
            "avg_dog_population": 1,
            "avg_cat_population": 1
        }
    }
]

# Execute the aggregation pipeline
result = list(collection.aggregate(pipeline))

# Print the result
if result:
    print(json.dumps(result[0], indent=4))
else:
    print("No data found.")
# Out:
# {
#     "avg_n_households": 2403.8979591836733,
#     "avg_dog_population": 1414.1632653061224,
#     "avg_cat_population": 1492.795918367347
# }

# %% [markdown]
# ## Save the record in the file
#
# This code writes the aggregation result (stored in the result list) to a JSON file located at the specified file path with proper indentation. It uses a with block to ensure that the file is properly closed after writing the data.

# %%
write_data=open("C:/Users/saivi/bd-f23/bd-f23/catsvsdogs_agg.json", "w")
write_data.write(json.dumps(list(result), indent=5))
write_data.close()
